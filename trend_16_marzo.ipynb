# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data  = pd.read_csv("data.csv")

# %%
t = data["time"]
logn = np.log(data["count"])

m,b = np.polyfit(t, logn, 1)

x = np.linspace(t.min(), t.max())
y = m*x + b
plt.semilogy(data["time"], data["count"], 'o')
plt.plot(x, np.exp(y))
plt.title('Doubling Time: {:.0f} hours'.format(24*np.log(2.0)/m))
plt.xlabel('Time [Days]')
plt.ylabel('Cumulative number of infections')
# Out:
# Text(0, 0.5, 'Cumulative number of infections')

# %%
x = np.linspace(t.min(), 23)
y = m*x + b
plt.semilogy(data["time"], data["count"], 'o')
plt.plot(x, np.exp(y))
plt.title('Doubling Time: {:.0f} hours'.format(24*np.log(2.0)/m))
plt.xlabel('Time [Days]')
plt.ylabel('Cumulative number of infections')
# Out:
# Text(0, 0.5, 'Cumulative number of infections')

# %%
# predictions
for i in range(8, 23):
    print("{} de Marzo \t {} casos".format(9+i, int(np.exp(m*i+b))))
# Out:
# 17 de Marzo 	 77 casos
# 18 de Marzo 	 114 casos
# 19 de Marzo 	 169 casos
# 20 de Marzo 	 250 casos
# 21 de Marzo 	 370 casos
# 22 de Marzo 	 547 casos
# 23 de Marzo 	 810 casos
# 24 de Marzo 	 1198 casos
# 25 de Marzo 	 1773 casos
# 26 de Marzo 	 2624 casos
# 27 de Marzo 	 3883 casos
# 28 de Marzo 	 5746 casos
# 29 de Marzo 	 8503 casos
# 30 de Marzo 	 12582 casos
# 31 de Marzo 	 18617 casos
