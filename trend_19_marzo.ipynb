# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data  = pd.read_csv("data.csv")

# %%
t = data["time"]
logn = np.log(data["count"])
last_n_days = 5
m,b = np.polyfit(t[-last_n_days:], logn[-last_n_days:], 1)

x = np.linspace(t.min(), t.max())
y = m*x + b
plt.semilogy(data["time"], data["count"], 'o')
plt.plot(x, np.exp(y))
plt.title('Doubling Time: {:.1f} days'.format(np.log(2.0)/m))
plt.xlabel('Time [Days]')
plt.ylabel('Cumulative number of infections')
# Out:
# Text(0,0.5,'Cumulative number of infections')

# %%
x = np.linspace(t.min(), 23)
y = m*x + b
plt.semilogy(data["time"], data["count"], 'o')
plt.plot(x, np.exp(y))
plt.title('Doubling Time: {:.0f} hours'.format(24*np.log(2.0)/m))
plt.xlabel('Time [Days]')
plt.ylabel('Cumulative number of infections')
# Out:
# Text(0,0.5,'Cumulative number of infections')

# %%
# predictions
for i in range(11, 23):
    print("{} de Marzo \t {} casos".format(9+i, int(np.exp(m*i+b))))
# Out:
# 20 de Marzo 	 147 casos
# 21 de Marzo 	 193 casos
# 22 de Marzo 	 254 casos
# 23 de Marzo 	 334 casos
# 24 de Marzo 	 440 casos
# 25 de Marzo 	 579 casos
# 26 de Marzo 	 762 casos
# 27 de Marzo 	 1002 casos
# 28 de Marzo 	 1318 casos
# 29 de Marzo 	 1734 casos
# 30 de Marzo 	 2281 casos
# 31 de Marzo 	 3000 casos
