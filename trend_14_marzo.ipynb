# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data  = pd.read_csv("data.csv")

# %%
t = data["time"]
logn = np.log(data["count"])

m,b = np.polyfit(t, logn, 1)

x = np.linspace(t.min(), t.max())
y = m*x + b
plt.semilogy(data["time"], data["count"], 'o')
plt.plot(x, np.exp(y))
plt.title('Doubling Time: {:.2f} days'.format(np.log(2.0)/m))
plt.xlabel('Time [Days]')
plt.ylabel('Cumulative number of infections')
# Out:
# Text(0,0.5,'Cumulative number of infections')

# %%
x = np.linspace(t.min(), 20)
y = m*x + b
plt.semilogy(data["time"], data["count"], 'o')
plt.plot(x, np.exp(y))
plt.title('Doubling Time: {:.2f} days'.format(np.log(2.0)/m))
plt.xlabel('Time [Days]')
plt.ylabel('Cumulative number of infections')
# Out:
# Text(0,0.5,'Cumulative number of infections')

# %%
# predictions
for i in range(20):
    print("{} de Marzo \t {} casos".format(9+i, int(np.exp(m*i+b))))
# Out:
# 9 de Marzo 	 3 casos
# 10 de Marzo 	 4 casos
# 11 de Marzo 	 7 casos
# 12 de Marzo 	 10 casos
# 13 de Marzo 	 16 casos
# 14 de Marzo 	 23 casos
# 15 de Marzo 	 35 casos
# 16 de Marzo 	 51 casos
# 17 de Marzo 	 76 casos
# 18 de Marzo 	 112 casos
# 19 de Marzo 	 166 casos
# 20 de Marzo 	 246 casos
# 21 de Marzo 	 363 casos
# 22 de Marzo 	 537 casos
# 23 de Marzo 	 793 casos
# 24 de Marzo 	 1172 casos
# 25 de Marzo 	 1730 casos
# 26 de Marzo 	 2556 casos
# 27 de Marzo 	 3775 casos
# 28 de Marzo 	 5576 casos
