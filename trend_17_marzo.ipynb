# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data  = pd.read_csv("data.csv")

# %%
t = data["time"]
logn = np.log(data["count"])

m,b = np.polyfit(t[-4:], logn[-4:], 1)

x = np.linspace(t.min(), t.max())
y = m*x + b
plt.semilogy(data["time"], data["count"], 'o')
plt.plot(x, np.exp(y))
plt.title('Doubling Time: {:.1f} days'.format(np.log(2.0)/m))
plt.xlabel('Time [Days]')
plt.ylabel('Cumulative number of infections')
# Out:
# Text(0,0.5,'Cumulative number of infections')

# %%
x = np.linspace(t.min(), 23)
y = m*x + b
plt.semilogy(data["time"], data["count"], 'o')
plt.plot(x, np.exp(y))
plt.title('Doubling Time: {:.0f} hours'.format(24*np.log(2.0)/m))
plt.xlabel('Time [Days]')
plt.ylabel('Cumulative number of infections')
# Out:
# Text(0,0.5,'Cumulative number of infections')

# %%
# predictions
for i in range(9, 23):
    print("{} de Marzo \t {} casos".format(9+i, int(np.exp(m*i+b))))
# Out:
# 18 de Marzo 	 101 casos
# 19 de Marzo 	 147 casos
# 20 de Marzo 	 213 casos
# 21 de Marzo 	 310 casos
# 22 de Marzo 	 449 casos
# 23 de Marzo 	 651 casos
# 24 de Marzo 	 944 casos
# 25 de Marzo 	 1369 casos
# 26 de Marzo 	 1985 casos
# 27 de Marzo 	 2877 casos
# 28 de Marzo 	 4171 casos
# 29 de Marzo 	 6046 casos
# 30 de Marzo 	 8765 casos
# 31 de Marzo 	 12705 casos
