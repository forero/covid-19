# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data  = pd.read_csv("data.csv")

# %%
t = data["time"]
logn = np.log(data["count"])

m,b = np.polyfit(t[-4:], logn[-4:], 1)

x = np.linspace(t.min(), t.max())
y = m*x + b
plt.semilogy(data["time"], data["count"], 'o')
plt.plot(x, np.exp(y))
plt.title('Doubling Time: {:.1f} days'.format(np.log(2.0)/m))
plt.xlabel('Time [Days]')
plt.ylabel('Cumulative number of infections')
# Out:
# Text(0,0.5,'Cumulative number of infections')

# %%
x = np.linspace(t.min(), 23)
y = m*x + b
plt.semilogy(data["time"], data["count"], 'o')
plt.plot(x, np.exp(y))
plt.title('Doubling Time: {:.0f} hours'.format(24*np.log(2.0)/m))
plt.xlabel('Time [Days]')
plt.ylabel('Cumulative number of infections')
# Out:
# Text(0,0.5,'Cumulative number of infections')

# %%
# predictions
for i in range(10, 23):
    print("{} de Marzo \t {} casos".format(9+i, int(np.exp(m*i+b))))
# Out:
# 19 de Marzo 	 128 casos
# 20 de Marzo 	 177 casos
# 21 de Marzo 	 244 casos
# 22 de Marzo 	 336 casos
# 23 de Marzo 	 463 casos
# 24 de Marzo 	 638 casos
# 25 de Marzo 	 879 casos
# 26 de Marzo 	 1211 casos
# 27 de Marzo 	 1668 casos
# 28 de Marzo 	 2299 casos
# 29 de Marzo 	 3167 casos
# 30 de Marzo 	 4364 casos
# 31 de Marzo 	 6012 casos
